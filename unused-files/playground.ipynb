# %%
import geopandas as gpd

# %%
edges = gpd.read_file("data/edges.shp")
nodes = gpd.read_file("data/nodes.shp")

# %%
print(edges.info())
print(edges.head())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 15021 entries, 0 to 15020
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   u         15021 non-null  int64
#  1   v         15021 non-null  int64
#  2   key       15021 non-null  int64
#  3   osmid     15021 non-null  object
#  4   oneway    15021 non-null  int32
#  5   name      14284 non-null  object
#  6   highway   15021 non-null  object
#  7   maxspeed  12324 non-null  object
#  8   length    15021 non-null  float64
#  9   lanes     1286 non-null   object
#  10  junction  425 non-null    object
#  11  ref       442 non-null    object
#  12  tunnel    261 non-null    object
#  13  bridge    444 non-null    object
#  14  access    258 non-null    object
#  15  width     17 non-null     object
#  16  fid       15021 non-null  int64
#  17  geometry  15021 non-null  geometry
# dtypes: float64(1), geometry(1), int32(1), int64(4), object(11)
# ...

# %%
print(nodes.info())
print(nodes.head())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6974 entries, 0 to 6973
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   y         6974 non-null   float64
#  1   x         6974 non-null   float64
#  2   osmid     6974 non-null   int64
#  3   highway   878 non-null    object
#  4   ref       47 non-null     object
#  5   geometry  6974 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(2)
# memory usage: 327.0+ KB
# None
#            y          x       osmid highway   ref                   geometry
# 0  59.322742  18.004948   365985796    None  None  POINT (18.00495 59.32274)
# 1  59.322837  18.004939   365985797    None  None  POINT (18.00494 59.32284)
# 2  59.291444  18.026892  1270710276    None  None  POINT (18.02689 59.29144)
# 3  59.302790  17.979597     6963207    None  None   POINT (17.9796 59.30279)
# ...
